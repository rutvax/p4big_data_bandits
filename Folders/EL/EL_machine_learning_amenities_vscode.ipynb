# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import tensorflow as tf

# %%
# Read in cleaned and encoded DataFrame from Google Colab and PySpark
model_df = pd.read_csv('model_df.csv')
model_df = model_df.drop('Unnamed: 0', axis=1)
model_df.dtypes
# Out:
# price                        float64
# room_type_Entire home/apt      int64
# room_type_Hotel room           int64
# room_type_Private room         int64
# room_type_Shared room          int64
# accommodates                   int64
# bedrooms                       int64
# beds                           int64
# bathrooms                    float64
# bathroom_type_private          int64
# bathroom_type_shared           int64
# neighbourhood_Brooklyn         int64
# neighbourhood_Manhattan        int64
# neighbourhood_Queens           int64
# wifi                           int64
# smoke_alarm                    int64
# carbon_monoxide_alarm          int64
# kitchen                        int64
# air_conditioning               int64
# tv                             int64
# iron                           int64
# essentials                     int64
# hangers                        int64
# shampoo                        int64
# refrigerator                   int64
# hair_dryer                     int64
# dishes_and_silverware          int64
# hot_water                      int64
# cooking_basics                 int64
# heating                        int64
# bed_linens                     int64
# microwave                      int64
# oven                           int64
# fire_extinguisher              int64
# coffee_maker                   int64
# free_street_parking            int64
# first_aid_kit                  int64
# self_check_in                  int64
# dedicated_workspace            int64
# dtype: object

# %% [markdown]
# # Logistic Regression

# %%
y = model_df["price"]
X = model_df.drop(columns="price")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_regr = regr.predict(X_test)

# Calculate Mean Squared Error (MSE)
mse_regr = mean_squared_error(y_test, y_pred_regr)

# Calculate Root Mean Squared Error (RMSE)
rmse_regr = np.sqrt(mse_regr)

# Calculate R-squared for the deep learning model
r2_regr = r2_score(y_test, y_pred_regr)

print("Linear Regression Model - Root Mean Squared Error (RMSE):", rmse_regr)
print("Linear Regression Model - R-squared:", r2_regr)
# Out:
# Linear Regression Model - Root Mean Squared Error (RMSE): 101.27787596535208
# Linear Regression Model - R-squared: 0.4485418030023708

# %%
# Score the model
print(f"Training Data Score: {regr.score(X_train, y_train)}")
print(f"Testing Data Score: {regr.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.437809110582532
# Testing Data Score: 0.4485418030023708

# %% [markdown]
# # Deep Learning

# %%
nn = tf.keras.models.Sequential()
nn.add(tf.keras.layers.Dense(units=38, activation="relu", input_dim=38))
nn.add(tf.keras.layers.Dense(units=20, activation="relu"))
nn.add(tf.keras.layers.Dense(units=20, activation="relu"))
nn.add(tf.keras.layers.Dense(units=20, activation="relu"))
nn.add(tf.keras.layers.Dense(units=1))

# %%
nn.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
fit_model = nn.fit(X_train, y_train, epochs=100, validation_split=0.25)
# Out:
# Epoch 1/100
# 476/476 [==============================] - 4s 4ms/step - loss: 21504.8594 - mean_absolute_error: 97.9053 - val_loss: 11330.7539 - val_mean_absolute_error: 66.3357
# Epoch 2/100
# 476/476 [==============================] - 2s 3ms/step - loss: 11318.0898 - mean_absolute_error: 68.0680 - val_loss: 10654.8994 - val_mean_absolute_error: 69.7835
# Epoch 3/100
# 476/476 [==============================] - 2s 4ms/step - loss: 10916.1650 - mean_absolute_error: 67.1671 - val_loss: 10173.9102 - val_mean_absolute_error: 65.0992
# Epoch 4/100
# 476/476 [==============================] - 2s 3ms/step - loss: 10658.3984 - mean_absolute_error: 66.2501 - val_loss: 9910.6182 - val_mean_absolute_error: 62.9521
# Epoch 5/100
# 476/476 [==============================] - 2s 3ms/step - loss: 10434.2109 - mean_absolute_error: 65.2122 - val_loss: 9738.4521 - val_mean_absolute_error: 61.3659
# Epoch 6/100
# 476/476 [==============================] - 1s 3ms/step - loss: 10196.9004 - mean_absolute_error: 64.1425 - val_loss: 9519.8936 - val_mean_absolute_error: 60.5662
# Epoch 7/100
# 476/476 [==============================] - 1s 3ms/step - loss: 10063.3643 - mean_absolute_error: 63.5727 - val_loss: 9650.0918 - val_mean_absolute_error: 66.4425
# Epoch 8/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9990.5664 - mean_absolute_error: 63.1432 - val_loss: 9315.2920 - val_mean_absolute_error: 60.6027
# Epoch 9/100
# 476/476 [==============================] - 1s 3ms/step - loss: 9937.2598 - mean_absolute_error: 62.8297 - val_loss: 9262.6807 - val_mean_absolute_error: 60.6929
# Epoch 10/100
# 476/476 [==============================] - 1s 3ms/step - loss: 9886.5449 - mean_absolute_error: 62.5484 - val_loss: 9224.2344 - val_mean_absolute_error: 61.5425
# Epoch 11/100
# 476/476 [==============================] - 1s 3ms/step - loss: 9822.5225 - mean_absolute_error: 62.4646 - val_loss: 9256.3125 - val_mean_absolute_error: 59.0490
# Epoch 12/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9778.1641 - mean_absolute_error: 62.1266 - val_loss: 9236.3652 - val_mean_absolute_error: 58.6744
# Epoch 13/100
# 476/476 [==============================] - 1s 3ms/step - loss: 9757.5674 - mean_absolute_error: 61.8531 - val_loss: 9069.3242 - val_mean_absolute_error: 59.6262
# Epoch 14/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9677.7188 - mean_absolute_error: 61.7304 - val_loss: 9061.3330 - val_mean_absolute_error: 59.6777
# Epoch 15/100
# 476/476 [==============================] - 1s 3ms/step - loss: 9670.9062 - mean_absolute_error: 61.5434 - val_loss: 9065.0996 - val_mean_absolute_error: 61.4814
# Epoch 16/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9606.1357 - mean_absolute_error: 61.3015 - val_loss: 9144.7705 - val_mean_absolute_error: 62.9387
# Epoch 17/100
# 476/476 [==============================] - 2s 4ms/step - loss: 9577.5410 - mean_absolute_error: 61.1132 - val_loss: 9022.0996 - val_mean_absolute_error: 58.4185
# Epoch 18/100
# 476/476 [==============================] - 2s 4ms/step - loss: 9539.4443 - mean_absolute_error: 61.0450 - val_loss: 9136.4688 - val_mean_absolute_error: 63.1419
# Epoch 19/100
# 476/476 [==============================] - 3s 6ms/step - loss: 9514.9229 - mean_absolute_error: 60.8551 - val_loss: 8920.3506 - val_mean_absolute_error: 59.3951
# Epoch 20/100
# 476/476 [==============================] - 2s 4ms/step - loss: 9488.4648 - mean_absolute_error: 60.7262 - val_loss: 8890.4102 - val_mean_absolute_error: 58.8146
# Epoch 21/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9461.5771 - mean_absolute_error: 60.7829 - val_loss: 8862.7734 - val_mean_absolute_error: 59.4401
# Epoch 22/100
# 476/476 [==============================] - 2s 4ms/step - loss: 9401.5771 - mean_absolute_error: 60.3802 - val_loss: 8835.5918 - val_mean_absolute_error: 59.0579
# Epoch 23/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9387.2988 - mean_absolute_error: 60.3978 - val_loss: 8980.6553 - val_mean_absolute_error: 57.7661
# Epoch 24/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9347.9072 - mean_absolute_error: 60.1164 - val_loss: 8838.8301 - val_mean_absolute_error: 59.6856
# Epoch 25/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9314.3174 - mean_absolute_error: 60.0987 - val_loss: 8841.1709 - val_mean_absolute_error: 59.8786
# Epoch 26/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9290.0361 - mean_absolute_error: 59.8540 - val_loss: 8799.0264 - val_mean_absolute_error: 59.2820
# Epoch 27/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9265.6943 - mean_absolute_error: 60.1126 - val_loss: 8957.9404 - val_mean_absolute_error: 61.8508
# Epoch 28/100
# 476/476 [==============================] - 1s 3ms/step - loss: 9242.4326 - mean_absolute_error: 59.6569 - val_loss: 8901.8770 - val_mean_absolute_error: 61.4128
# Epoch 29/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9239.6182 - mean_absolute_error: 59.7247 - val_loss: 8787.8799 - val_mean_absolute_error: 58.5401
# Epoch 30/100
# 476/476 [==============================] - 1s 3ms/step - loss: 9206.0156 - mean_absolute_error: 59.6873 - val_loss: 8790.4980 - val_mean_absolute_error: 57.8114
# Epoch 31/100
# 476/476 [==============================] - 1s 3ms/step - loss: 9166.3145 - mean_absolute_error: 59.5828 - val_loss: 8766.8135 - val_mean_absolute_error: 58.0893
# Epoch 32/100
# 476/476 [==============================] - 2s 4ms/step - loss: 9142.3584 - mean_absolute_error: 59.3934 - val_loss: 8891.8945 - val_mean_absolute_error: 60.9823
# Epoch 33/100
# 476/476 [==============================] - 2s 4ms/step - loss: 9149.8320 - mean_absolute_error: 59.3460 - val_loss: 9015.5889 - val_mean_absolute_error: 57.3255
# Epoch 34/100
# 476/476 [==============================] - 3s 6ms/step - loss: 9110.1426 - mean_absolute_error: 59.2926 - val_loss: 8950.0303 - val_mean_absolute_error: 61.9389
# Epoch 35/100
# 476/476 [==============================] - 3s 6ms/step - loss: 9075.1777 - mean_absolute_error: 59.2715 - val_loss: 9078.4346 - val_mean_absolute_error: 57.0834
# Epoch 36/100
# 476/476 [==============================] - 3s 6ms/step - loss: 9094.6309 - mean_absolute_error: 59.4833 - val_loss: 8781.5605 - val_mean_absolute_error: 60.3441
# Epoch 37/100
# 476/476 [==============================] - 2s 4ms/step - loss: 9057.3623 - mean_absolute_error: 59.1730 - val_loss: 8771.9980 - val_mean_absolute_error: 59.3684
# Epoch 38/100
# 476/476 [==============================] - 2s 4ms/step - loss: 9030.5088 - mean_absolute_error: 59.0788 - val_loss: 8740.2578 - val_mean_absolute_error: 57.9278
# Epoch 39/100
# 476/476 [==============================] - 2s 3ms/step - loss: 9015.0840 - mean_absolute_error: 59.1315 - val_loss: 8715.1123 - val_mean_absolute_error: 58.2251
# Epoch 40/100
# 476/476 [==============================] - 2s 4ms/step - loss: 9001.3428 - mean_absolute_error: 58.9845 - val_loss: 8739.7109 - val_mean_absolute_error: 59.9279
# Epoch 41/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8963.8105 - mean_absolute_error: 59.0580 - val_loss: 8773.1680 - val_mean_absolute_error: 56.7518
# Epoch 42/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8989.8906 - mean_absolute_error: 58.9632 - val_loss: 8678.7090 - val_mean_absolute_error: 58.3457
# Epoch 43/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8947.2061 - mean_absolute_error: 58.8509 - val_loss: 8689.7246 - val_mean_absolute_error: 59.6456
# Epoch 44/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8942.8965 - mean_absolute_error: 58.8679 - val_loss: 8677.3164 - val_mean_absolute_error: 59.1257
# Epoch 45/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8917.2402 - mean_absolute_error: 58.7621 - val_loss: 8665.5371 - val_mean_absolute_error: 57.9976
# Epoch 46/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8900.9375 - mean_absolute_error: 58.7408 - val_loss: 8853.9404 - val_mean_absolute_error: 56.8196
# Epoch 47/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8901.8936 - mean_absolute_error: 58.7118 - val_loss: 8638.7871 - val_mean_absolute_error: 59.0175
# Epoch 48/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8897.0713 - mean_absolute_error: 58.7063 - val_loss: 8641.8252 - val_mean_absolute_error: 57.5609
# Epoch 49/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8884.7695 - mean_absolute_error: 58.6850 - val_loss: 8689.9648 - val_mean_absolute_error: 57.1601
# Epoch 50/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8827.7090 - mean_absolute_error: 58.5681 - val_loss: 8799.7168 - val_mean_absolute_error: 56.9583
# Epoch 51/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8816.0303 - mean_absolute_error: 58.4437 - val_loss: 8941.9678 - val_mean_absolute_error: 62.9842
# Epoch 52/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8802.3291 - mean_absolute_error: 58.4213 - val_loss: 8640.4473 - val_mean_absolute_error: 58.9537
# Epoch 53/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8788.8779 - mean_absolute_error: 58.3380 - val_loss: 8690.7598 - val_mean_absolute_error: 59.6988
# Epoch 54/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8794.2031 - mean_absolute_error: 58.4969 - val_loss: 8656.0371 - val_mean_absolute_error: 59.5520
# Epoch 55/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8715.7207 - mean_absolute_error: 58.0885 - val_loss: 9147.3584 - val_mean_absolute_error: 63.6592
# Epoch 56/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8729.9473 - mean_absolute_error: 58.2426 - val_loss: 8589.1748 - val_mean_absolute_error: 58.0616
# Epoch 57/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8707.3818 - mean_absolute_error: 58.0571 - val_loss: 8792.2754 - val_mean_absolute_error: 61.0519
# Epoch 58/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8725.4766 - mean_absolute_error: 58.2430 - val_loss: 8766.6943 - val_mean_absolute_error: 61.2617
# Epoch 59/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8678.3906 - mean_absolute_error: 58.0647 - val_loss: 8655.4150 - val_mean_absolute_error: 59.5708
# Epoch 60/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8703.6865 - mean_absolute_error: 58.1447 - val_loss: 8661.9268 - val_mean_absolute_error: 57.1034
# Epoch 61/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8678.4111 - mean_absolute_error: 58.1051 - val_loss: 8623.9785 - val_mean_absolute_error: 58.4268
# Epoch 62/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8625.9551 - mean_absolute_error: 57.8991 - val_loss: 8602.5088 - val_mean_absolute_error: 59.1533
# Epoch 63/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8664.5020 - mean_absolute_error: 58.0614 - val_loss: 8833.9688 - val_mean_absolute_error: 61.0431
# Epoch 64/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8627.9482 - mean_absolute_error: 57.8831 - val_loss: 8549.3369 - val_mean_absolute_error: 57.8220
# Epoch 65/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8622.1836 - mean_absolute_error: 57.8628 - val_loss: 8665.8252 - val_mean_absolute_error: 59.3314
# Epoch 66/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8554.2539 - mean_absolute_error: 57.7116 - val_loss: 8766.2002 - val_mean_absolute_error: 58.3623
# Epoch 67/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8603.7441 - mean_absolute_error: 57.9500 - val_loss: 8799.5859 - val_mean_absolute_error: 56.9326
# Epoch 68/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8559.2441 - mean_absolute_error: 57.7112 - val_loss: 8583.2246 - val_mean_absolute_error: 57.8155
# Epoch 69/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8545.4912 - mean_absolute_error: 57.7352 - val_loss: 8624.0459 - val_mean_absolute_error: 57.8057
# Epoch 70/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8505.1846 - mean_absolute_error: 57.5915 - val_loss: 8802.8594 - val_mean_absolute_error: 61.6022
# Epoch 71/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8519.9717 - mean_absolute_error: 57.7807 - val_loss: 8614.1270 - val_mean_absolute_error: 58.1973
# Epoch 72/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8506.2041 - mean_absolute_error: 57.4848 - val_loss: 8760.0488 - val_mean_absolute_error: 57.0952
# Epoch 73/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8460.9326 - mean_absolute_error: 57.4093 - val_loss: 8814.3955 - val_mean_absolute_error: 62.6340
# Epoch 74/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8466.6992 - mean_absolute_error: 57.5844 - val_loss: 8560.2627 - val_mean_absolute_error: 58.1364
# Epoch 75/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8468.0850 - mean_absolute_error: 57.5581 - val_loss: 8610.5127 - val_mean_absolute_error: 58.7673
# Epoch 76/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8451.4639 - mean_absolute_error: 57.4804 - val_loss: 8543.9688 - val_mean_absolute_error: 57.9152
# Epoch 77/100
# 476/476 [==============================] - 2s 5ms/step - loss: 8468.7695 - mean_absolute_error: 57.5793 - val_loss: 8958.5322 - val_mean_absolute_error: 56.9741
# Epoch 78/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8365.6611 - mean_absolute_error: 57.1263 - val_loss: 8603.7607 - val_mean_absolute_error: 57.8669
# Epoch 79/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8429.9570 - mean_absolute_error: 57.4353 - val_loss: 8919.6416 - val_mean_absolute_error: 56.8578
# Epoch 80/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8455.1318 - mean_absolute_error: 57.4401 - val_loss: 8715.0918 - val_mean_absolute_error: 56.8663
# Epoch 81/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8364.5244 - mean_absolute_error: 57.2515 - val_loss: 8719.1885 - val_mean_absolute_error: 57.6160
# Epoch 82/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8354.4883 - mean_absolute_error: 57.0731 - val_loss: 8613.7812 - val_mean_absolute_error: 58.5399
# Epoch 83/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8354.6768 - mean_absolute_error: 57.2606 - val_loss: 8629.1162 - val_mean_absolute_error: 57.4010
# Epoch 84/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8342.7861 - mean_absolute_error: 57.2140 - val_loss: 8666.1631 - val_mean_absolute_error: 57.6367
# Epoch 85/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8356.8857 - mean_absolute_error: 57.1221 - val_loss: 8706.5020 - val_mean_absolute_error: 57.1350
# Epoch 86/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8326.8428 - mean_absolute_error: 57.0068 - val_loss: 8611.2432 - val_mean_absolute_error: 58.2012
# Epoch 87/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8294.8350 - mean_absolute_error: 57.1485 - val_loss: 8544.2061 - val_mean_absolute_error: 58.1047
# Epoch 88/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8261.9268 - mean_absolute_error: 56.9126 - val_loss: 8568.8594 - val_mean_absolute_error: 57.7542
# Epoch 89/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8262.4434 - mean_absolute_error: 56.7933 - val_loss: 8727.4609 - val_mean_absolute_error: 57.2796
# Epoch 90/100
# 476/476 [==============================] - 1s 3ms/step - loss: 8227.9561 - mean_absolute_error: 56.7005 - val_loss: 8788.3936 - val_mean_absolute_error: 57.5968
# Epoch 91/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8253.7969 - mean_absolute_error: 56.9207 - val_loss: 8674.9697 - val_mean_absolute_error: 58.1747
# Epoch 92/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8202.0645 - mean_absolute_error: 56.7020 - val_loss: 8724.8584 - val_mean_absolute_error: 58.7559
# Epoch 93/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8194.5615 - mean_absolute_error: 56.6718 - val_loss: 8640.9932 - val_mean_absolute_error: 57.7219
# Epoch 94/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8215.4580 - mean_absolute_error: 56.7125 - val_loss: 8642.4189 - val_mean_absolute_error: 59.5424
# Epoch 95/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8219.8691 - mean_absolute_error: 56.7695 - val_loss: 8639.9004 - val_mean_absolute_error: 58.6002
# Epoch 96/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8191.2188 - mean_absolute_error: 56.7371 - val_loss: 8627.8877 - val_mean_absolute_error: 58.1168
# Epoch 97/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8181.0679 - mean_absolute_error: 56.6003 - val_loss: 8703.5322 - val_mean_absolute_error: 56.7383
# Epoch 98/100
# 476/476 [==============================] - 2s 5ms/step - loss: 8114.8735 - mean_absolute_error: 56.4028 - val_loss: 8637.9199 - val_mean_absolute_error: 60.4009
# Epoch 99/100
# 476/476 [==============================] - 2s 3ms/step - loss: 8151.4614 - mean_absolute_error: 56.5386 - val_loss: 8659.2061 - val_mean_absolute_error: 57.3713
# Epoch 100/100
# 476/476 [==============================] - 2s 4ms/step - loss: 8128.5664 - mean_absolute_error: 56.5401 - val_loss: 8689.2285 - val_mean_absolute_error: 59.0189

# %%
model_loss, model_accuracy = nn.evaluate(X_test, y_test)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 212/212 [==============================] - 1s 2ms/step - loss: 8489.4795 - mean_absolute_error: 58.8236
# Loss: 8489.4794921875, Accuracy: 58.82362747192383

# %%
# Calculate predictions using the deep learning model
y_pred_nn = nn.predict(X_test)

# Calculate Mean Squared Error (MSE) for the deep learning model
mse_nn = mean_squared_error(y_test, y_pred_nn)

# Calculate Root Mean Squared Error (RMSE) for the deep learning model
rmse_nn = np.sqrt(mse_nn)

# Calculate R-squared for the deep learning model
r2_nn = r2_score(y_test, y_pred_nn)

print("Deep Learning Model - Root Mean Squared Error (RMSE):", rmse_nn)
print("Deep Learning Model - R-squared:", r2_nn)
# Out:
# 212/212 [==============================] - 1s 3ms/step
# Deep Learning Model - Root Mean Squared Error (RMSE): 92.13838153240141
# Deep Learning Model - R-squared: 0.5435800847128894

# %%
# Export to pickle file
import pickle

with open('EL_machine_learning_model.pkl', 'wb') as model_file:
    pickle.dump(nn, model_file)

# %%
# Export to joblib file
import joblib

joblib.dump(nn, 'EL_machine_learning_model.joblib')
# Out:
# ['EL_machine_learning_model.joblib']
