# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf
from geopy.geocoders import Nominatim

# %%
# Import our input dataset
ny_df = pd.read_csv('column_listings_df.csv', nrows=2000)
ny_df.head()
# Out:
#            listing_id                                      listing_url  \
# 0            52702018            https://www.airbnb.com/rooms/52702018
# 1  784969376930125242  https://www.airbnb.com/rooms/784969376930125242
# 2             9919728             https://www.airbnb.com/rooms/9919728
# 3            53696990            https://www.airbnb.com/rooms/53696990
# 4             9920363             https://www.airbnb.com/rooms/9920363
#
#                                                 name   host_id  \
# 0  Rental unit in Queens · ★4.90 · 1 bedroom · 2 ...  93231383
# 1  Home in Queens · ★4.97 · 3 bedrooms · 4 beds ·...  93231383
# 2  Townhouse in Queens · ★4.33 · 3 bedrooms · 7 b...  50997424
# 3  Vacation home in Queens · Studio · 2 beds · 1 ...  50997424
# 4  Townhouse in Queens · ★4.25 · 5 bedrooms · 11 ...  50997424
#
#                                      host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/93231383    Daniel  2016-09-03
# 1  https://www.airbnb.com/users/show/93231383    Daniel  2016-09-03
# 2  https://www.airbnb.com/users/show/50997424      Mark  2015-12-10
# 3  https://www.airbnb.com/users/show/50997424      Mark  2015-12-10
# 4  https://www.airbnb.com/users/show/50997424      Mark  2015-12-10
#
#   host_is_superhost  host_listings_count  host_total_listings_count  ...  \
# 0                 t                    3                          3  ...
# 1                 t                    3                          3  ...
# 2                 f                   10                         10  ...
# 3                 f                   10                         10  ...
# 4                 f                   10                         10  ...
#
#   last_review review_scores_rating  review_scores_accuracy  \
# 0  2023-08-21                 4.90                    4.95
# 1  2023-08-15                 4.97                    4.97
# 2  2020-02-18                 4.33                    4.17
# 3  2022-09-16                 4.00                    4.00
# 4  2020-01-01                 4.25                    4.25
#
#    review_scores_cleanliness review_scores_checkin  \
# 0                       4.90                  4.95
# 1                       4.97                  4.95
# 2                       4.33                  4.83
# 3                       3.00                  5.00
# 4                       3.75                  4.75
#
#    review_scores_communication review_scores_location  review_scores_value  \
# 0                         4.94                   4.85                 4.87
# 1                         4.95                   4.84                 4.87
# 2                         4.67                   4.83                 4.33
# 3                         4.00                   5.00                 3.00
# 4                         4.00                   4.75                 4.50
#
#    calculated_host_listings_count reviews_per_month
# 0                               3              8.53
# 1                               3              4.47
# 2                               7              0.09
# 3                               7              0.08
# 4                               7              0.09
#
# [5 rows x 38 columns]

# %%
ny_df.columns
# Out:
# Index(['listing_id', 'listing_url', 'name', 'host_id', 'host_url', 'host_name',
#        'host_since', 'host_is_superhost', 'host_listings_count',
#        'host_total_listings_count', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude', 'room_type',
#        'accommodates', 'bathrooms_text', 'bedrooms', 'beds', 'amenities',
#        'price', 'minimum_nights', 'maximum_nights', 'has_availability',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
ny_df=ny_df[['room_type','accommodates', 'bedrooms','neighbourhood_cleansed','price']]

ny_df['bedrooms']= ny_df['bedrooms'].fillna(1)
ny_df['price']= ny_df['price'].str.extract('(\d+\.\d+|\d+)').astype(float)

ny_df.head(3)
# Out:
#          room_type  accommodates  bedrooms neighbourhood_cleansed  price
# 0  Entire home/apt             4       1.0          East Elmhurst  171.0
# 1  Entire home/apt             7       3.0          East Elmhurst  311.0
# 2  Entire home/apt            12       3.0         Middle Village  328.0

# %%
# Encode data
encode_df = pd.get_dummies(ny_df, columns=['room_type', 'neighbourhood_cleansed'], prefix=['room_type', 'neighbourhood_cleansed'])
encode_df.head(3)
# Out:
#    accommodates  bedrooms  price  room_type_Entire home/apt  \
# 0             4       1.0  171.0                          1
# 1             7       3.0  311.0                          1
# 2            12       3.0  328.0                          1
#
#    room_type_Private room  room_type_Shared room  \
# 0                       0                      0
# 1                       0                      0
# 2                       0                      0
#
#    neighbourhood_cleansed_Arverne  neighbourhood_cleansed_Astoria  \
# 0                               0                               0
# 1                               0                               0
# 2                               0                               0
#
#    neighbourhood_cleansed_Bath Beach  \
# 0                                  0
# 1                                  0
# 2                                  0
#
#    neighbourhood_cleansed_Battery Park City  ...  \
# 0                                         0  ...
# 1                                         0  ...
# 2                                         0  ...
#
#    neighbourhood_cleansed_Tribeca  neighbourhood_cleansed_Two Bridges  \
# 0                               0                                   0
# 1                               0                                   0
# 2                               0                                   0
#
#    neighbourhood_cleansed_Upper East Side  \
# 0                                       0
# 1                                       0
# 2                                       0
#
#    neighbourhood_cleansed_Upper West Side  \
# 0                                       0
# 1                                       0
# 2                                       0
#
#    neighbourhood_cleansed_Washington Heights  \
# 0                                          0
# 1                                          0
# 2                                          0
#
#    neighbourhood_cleansed_Whitestone  neighbourhood_cleansed_Williamsburg  \
# 0                                  0                                    0
# 1                                  0                                    0
# 2                                  0                                    0
#
#    neighbourhood_cleansed_Windsor Terrace  neighbourhood_cleansed_Woodhaven  \
# 0                                       0                                 0
# 1                                       0                                 0
# 2                                       0                                 0
#
#    neighbourhood_cleansed_Woodside
# 0                                0
# 1                                0
# 2                                0
#
# [3 rows x 105 columns]

# %%
encode_df.dtypes
# Out:
# accommodates                                int64
# bedrooms                                  float64
# price                                     float64
# room_type_Entire home/apt                   uint8
# room_type_Private room                      uint8
#                                            ...
# neighbourhood_cleansed_Whitestone           uint8
# neighbourhood_cleansed_Williamsburg         uint8
# neighbourhood_cleansed_Windsor Terrace      uint8
# neighbourhood_cleansed_Woodhaven            uint8
# neighbourhood_cleansed_Woodside             uint8
# Length: 105, dtype: object

# %%
encode_df = encode_df.dropna()

# %%
y = encode_df.price.values
X = encode_df.drop(columns="price").values

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# LogisticRegression

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regr.predict(X_test)

# %%
# Assuming you already have predictions for the test dataset
y_pred = regr.predict(X_test)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 15039081306.734959

# %%
# Score the model
print(f"Training Data Score: {regr.score(X_train, y_train)}")
print(f"Testing Data Score: {regr.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.6688299633974548
# Testing Data Score: -9917188980211504.0

# %% [markdown]
# #Deep Learning

# %%
nn = tf.keras.models.Sequential()
nn.add(tf.keras.layers.Dense(units=104, activation="relu", input_dim=104))
nn.add(tf.keras.layers.Dense(units=80, activation="relu"))
nn.add(tf.keras.layers.Dense(units=80, activation="relu"))
nn.add(tf.keras.layers.Dense(units=80, activation="relu"))
nn.add(tf.keras.layers.Dense(units=1))

nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 104)               10920
#
#  dense_1 (Dense)             (None, 80)                8400
#
#  dense_2 (Dense)             (None, 80)                6480
#
#  dense_3 (Dense)             (None, 80)                6480
#
#  dense_4 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 32361 (126.41 KB)
# Trainable params: 32361 (126.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
#fit_model = nn.fit(X_train,y_train,epochs=30)

fit_model = nn.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 4ms/step - loss: 31871.5762 - mean_absolute_error: 121.3810 - val_loss: 25512.3457 - val_mean_absolute_error: 93.6604
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 13321.7783 - mean_absolute_error: 68.9931 - val_loss: 13280.3691 - val_mean_absolute_error: 63.0869
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 11028.9102 - mean_absolute_error: 61.2997 - val_loss: 12714.9863 - val_mean_absolute_error: 61.7367
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 10383.9893 - mean_absolute_error: 56.7060 - val_loss: 12599.4502 - val_mean_absolute_error: 64.6516
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 9883.4609 - mean_absolute_error: 54.8512 - val_loss: 12087.8096 - val_mean_absolute_error: 56.2507
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 9355.5156 - mean_absolute_error: 53.4124 - val_loss: 11894.9404 - val_mean_absolute_error: 54.2547
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 8845.6445 - mean_absolute_error: 52.3952 - val_loss: 11430.1553 - val_mean_absolute_error: 53.5079
# Epoch 8/100
# 38/38 [==============================] - 0s 2ms/step - loss: 8394.1318 - mean_absolute_error: 48.7373 - val_loss: 11103.2402 - val_mean_absolute_error: 62.6998
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 7881.2168 - mean_absolute_error: 50.7057 - val_loss: 10261.4346 - val_mean_absolute_error: 56.4037
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 7143.8394 - mean_absolute_error: 47.3471 - val_loss: 9784.6699 - val_mean_absolute_error: 51.5540
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 6823.9009 - mean_absolute_error: 46.8285 - val_loss: 9242.5186 - val_mean_absolute_error: 51.9681
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 6171.0864 - mean_absolute_error: 44.5447 - val_loss: 8838.5547 - val_mean_absolute_error: 50.6882
# Epoch 13/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5870.4287 - mean_absolute_error: 43.4877 - val_loss: 8759.4688 - val_mean_absolute_error: 49.9895
# Epoch 14/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5631.9258 - mean_absolute_error: 42.3250 - val_loss: 8499.2871 - val_mean_absolute_error: 49.2089
# Epoch 15/100
# 38/38 [==============================] - 0s 1ms/step - loss: 5768.9785 - mean_absolute_error: 42.3724 - val_loss: 9017.4688 - val_mean_absolute_error: 56.5398
# Epoch 16/100
# 38/38 [==============================] - 0s 1ms/step - loss: 5396.8115 - mean_absolute_error: 41.4558 - val_loss: 8557.0537 - val_mean_absolute_error: 48.8444
# Epoch 17/100
# 38/38 [==============================] - 0s 1ms/step - loss: 5254.6230 - mean_absolute_error: 40.4940 - val_loss: 8192.8594 - val_mean_absolute_error: 48.9447
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5318.0654 - mean_absolute_error: 41.4943 - val_loss: 8323.2070 - val_mean_absolute_error: 48.8506
# Epoch 19/100
# 38/38 [==============================] - 0s 1ms/step - loss: 5083.0981 - mean_absolute_error: 39.3985 - val_loss: 8658.7930 - val_mean_absolute_error: 54.7479
# Epoch 20/100
# 38/38 [==============================] - 0s 1ms/step - loss: 5031.8110 - mean_absolute_error: 39.4372 - val_loss: 8424.2930 - val_mean_absolute_error: 49.0476
# Epoch 21/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4930.0283 - mean_absolute_error: 39.1784 - val_loss: 8218.2676 - val_mean_absolute_error: 49.4638
# Epoch 22/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4671.6733 - mean_absolute_error: 36.9956 - val_loss: 8170.3218 - val_mean_absolute_error: 48.6689
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 4788.4941 - mean_absolute_error: 37.8792 - val_loss: 8217.9697 - val_mean_absolute_error: 49.6713
# Epoch 24/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4596.5439 - mean_absolute_error: 37.0923 - val_loss: 8235.7520 - val_mean_absolute_error: 49.2401
# Epoch 25/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4549.8936 - mean_absolute_error: 36.5152 - val_loss: 8805.2217 - val_mean_absolute_error: 52.2695
# Epoch 26/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4487.6411 - mean_absolute_error: 36.6162 - val_loss: 8279.2588 - val_mean_absolute_error: 48.9111
# Epoch 27/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4470.5220 - mean_absolute_error: 36.8410 - val_loss: 8343.0771 - val_mean_absolute_error: 48.4923
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 4524.4727 - mean_absolute_error: 36.4619 - val_loss: 8976.1396 - val_mean_absolute_error: 54.2074
# Epoch 29/100
# 38/38 [==============================] - 0s 2ms/step - loss: 4307.6304 - mean_absolute_error: 35.3922 - val_loss: 8354.3096 - val_mean_absolute_error: 48.8079
# Epoch 30/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4292.2720 - mean_absolute_error: 35.7869 - val_loss: 8904.7969 - val_mean_absolute_error: 53.0485
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 4441.0073 - mean_absolute_error: 36.6176 - val_loss: 8371.4834 - val_mean_absolute_error: 48.7065
# Epoch 32/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4251.3613 - mean_absolute_error: 35.8275 - val_loss: 8301.0225 - val_mean_absolute_error: 48.7637
# Epoch 33/100
# 38/38 [==============================] - 0s 2ms/step - loss: 4269.4375 - mean_absolute_error: 35.2910 - val_loss: 8612.1270 - val_mean_absolute_error: 51.5834
# Epoch 34/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4157.6533 - mean_absolute_error: 34.7292 - val_loss: 8677.5195 - val_mean_absolute_error: 49.5728
# Epoch 35/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4213.6245 - mean_absolute_error: 35.8731 - val_loss: 8941.9971 - val_mean_absolute_error: 52.1708
# Epoch 36/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4134.2466 - mean_absolute_error: 35.7666 - val_loss: 8693.8320 - val_mean_absolute_error: 51.0980
# Epoch 37/100
# 38/38 [==============================] - 0s 1ms/step - loss: 4048.5703 - mean_absolute_error: 34.9274 - val_loss: 8587.3086 - val_mean_absolute_error: 49.5638
# Epoch 38/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3989.9641 - mean_absolute_error: 34.4454 - val_loss: 9186.4980 - val_mean_absolute_error: 52.6409
# Epoch 39/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3932.7605 - mean_absolute_error: 34.2619 - val_loss: 8573.8438 - val_mean_absolute_error: 49.7601
# Epoch 40/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3843.7095 - mean_absolute_error: 33.7683 - val_loss: 8562.0537 - val_mean_absolute_error: 48.0207
# Epoch 41/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3927.1116 - mean_absolute_error: 34.8724 - val_loss: 8620.0244 - val_mean_absolute_error: 49.4598
# Epoch 42/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3901.3655 - mean_absolute_error: 34.5020 - val_loss: 9196.9404 - val_mean_absolute_error: 56.2234
# Epoch 43/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3941.6580 - mean_absolute_error: 34.7431 - val_loss: 8745.2920 - val_mean_absolute_error: 51.7833
# Epoch 44/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3792.1775 - mean_absolute_error: 33.4642 - val_loss: 8710.6709 - val_mean_absolute_error: 50.0825
# Epoch 45/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3662.0120 - mean_absolute_error: 32.7641 - val_loss: 8476.7451 - val_mean_absolute_error: 48.5265
# Epoch 46/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3668.9675 - mean_absolute_error: 33.1118 - val_loss: 8769.4434 - val_mean_absolute_error: 50.7492
# Epoch 47/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3654.8557 - mean_absolute_error: 33.0217 - val_loss: 8355.0938 - val_mean_absolute_error: 48.0225
# Epoch 48/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3987.7949 - mean_absolute_error: 34.7870 - val_loss: 9842.3486 - val_mean_absolute_error: 55.9641
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3630.3037 - mean_absolute_error: 33.0892 - val_loss: 8981.3477 - val_mean_absolute_error: 49.7269
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3591.6274 - mean_absolute_error: 32.3841 - val_loss: 8607.5518 - val_mean_absolute_error: 48.2041
# Epoch 51/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3821.5830 - mean_absolute_error: 34.0885 - val_loss: 10775.4395 - val_mean_absolute_error: 62.4019
# Epoch 52/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3715.0933 - mean_absolute_error: 33.7272 - val_loss: 8557.7861 - val_mean_absolute_error: 48.5145
# Epoch 53/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3611.2280 - mean_absolute_error: 33.2128 - val_loss: 9273.5146 - val_mean_absolute_error: 54.7716
# Epoch 54/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3840.3059 - mean_absolute_error: 35.0682 - val_loss: 8665.7354 - val_mean_absolute_error: 47.8933
# Epoch 55/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3563.3479 - mean_absolute_error: 34.4069 - val_loss: 8520.6221 - val_mean_absolute_error: 47.9690
# Epoch 56/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3463.6294 - mean_absolute_error: 32.6256 - val_loss: 9689.7666 - val_mean_absolute_error: 53.7915
# Epoch 57/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3521.1558 - mean_absolute_error: 32.5902 - val_loss: 8682.9639 - val_mean_absolute_error: 48.4419
# Epoch 58/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3454.1533 - mean_absolute_error: 32.4977 - val_loss: 8739.1650 - val_mean_absolute_error: 49.5224
# Epoch 59/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3448.9607 - mean_absolute_error: 31.7358 - val_loss: 9227.6689 - val_mean_absolute_error: 51.9594
# Epoch 60/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3361.8320 - mean_absolute_error: 31.8664 - val_loss: 9073.9990 - val_mean_absolute_error: 49.2593
# Epoch 61/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3336.8411 - mean_absolute_error: 31.6948 - val_loss: 8446.8242 - val_mean_absolute_error: 47.8328
# Epoch 62/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3306.2554 - mean_absolute_error: 30.7525 - val_loss: 9360.0625 - val_mean_absolute_error: 51.6331
# Epoch 63/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3277.7156 - mean_absolute_error: 31.3029 - val_loss: 8448.5986 - val_mean_absolute_error: 47.1606
# Epoch 64/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3258.8201 - mean_absolute_error: 31.2811 - val_loss: 8556.0244 - val_mean_absolute_error: 48.6710
# Epoch 65/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3323.4749 - mean_absolute_error: 31.2131 - val_loss: 8958.1982 - val_mean_absolute_error: 49.9578
# Epoch 66/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3238.8542 - mean_absolute_error: 30.7123 - val_loss: 9257.5566 - val_mean_absolute_error: 50.4276
# Epoch 67/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3491.4192 - mean_absolute_error: 32.3894 - val_loss: 8686.7324 - val_mean_absolute_error: 48.5475
# Epoch 68/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3204.0808 - mean_absolute_error: 30.5283 - val_loss: 8584.2471 - val_mean_absolute_error: 49.5746
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3156.7727 - mean_absolute_error: 30.4541 - val_loss: 8515.3438 - val_mean_absolute_error: 47.4866
# Epoch 70/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3388.2734 - mean_absolute_error: 31.3163 - val_loss: 8519.9805 - val_mean_absolute_error: 49.9316
# Epoch 71/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3633.1355 - mean_absolute_error: 34.8414 - val_loss: 9830.1904 - val_mean_absolute_error: 52.8223
# Epoch 72/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3200.5557 - mean_absolute_error: 30.9401 - val_loss: 9229.2520 - val_mean_absolute_error: 50.6714
# Epoch 73/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3201.5623 - mean_absolute_error: 30.3573 - val_loss: 8477.9883 - val_mean_absolute_error: 48.3525
# Epoch 74/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3258.8145 - mean_absolute_error: 31.1337 - val_loss: 9194.3867 - val_mean_absolute_error: 52.0591
# Epoch 75/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3179.1367 - mean_absolute_error: 30.3033 - val_loss: 8383.8213 - val_mean_absolute_error: 47.0056
# Epoch 76/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3282.0476 - mean_absolute_error: 30.4768 - val_loss: 8576.0088 - val_mean_absolute_error: 48.6613
# Epoch 77/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3111.9299 - mean_absolute_error: 29.7838 - val_loss: 8903.8408 - val_mean_absolute_error: 48.3632
# Epoch 78/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3287.1738 - mean_absolute_error: 30.5146 - val_loss: 9090.2822 - val_mean_absolute_error: 51.0216
# Epoch 79/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3195.6909 - mean_absolute_error: 30.3960 - val_loss: 8624.8271 - val_mean_absolute_error: 50.0502
# Epoch 80/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3129.1775 - mean_absolute_error: 29.8534 - val_loss: 10306.4316 - val_mean_absolute_error: 56.3930
# Epoch 81/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3075.2307 - mean_absolute_error: 29.9225 - val_loss: 9676.0527 - val_mean_absolute_error: 52.3062
# Epoch 82/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3245.7668 - mean_absolute_error: 31.3731 - val_loss: 8328.5234 - val_mean_absolute_error: 47.3066
# Epoch 83/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3014.9224 - mean_absolute_error: 29.5691 - val_loss: 8439.9404 - val_mean_absolute_error: 47.8334
# Epoch 84/100
# 38/38 [==============================] - 0s 1ms/step - loss: 2983.5764 - mean_absolute_error: 29.0144 - val_loss: 8620.6309 - val_mean_absolute_error: 48.9740
# Epoch 85/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3029.6641 - mean_absolute_error: 30.1781 - val_loss: 8670.7178 - val_mean_absolute_error: 50.1608
# Epoch 86/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3026.0095 - mean_absolute_error: 29.3925 - val_loss: 8521.2051 - val_mean_absolute_error: 47.6476
# Epoch 87/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3132.2522 - mean_absolute_error: 30.7514 - val_loss: 9495.4258 - val_mean_absolute_error: 52.3855
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2998.8257 - mean_absolute_error: 29.7067 - val_loss: 8437.6260 - val_mean_absolute_error: 47.9306
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2987.8318 - mean_absolute_error: 29.3228 - val_loss: 8497.5850 - val_mean_absolute_error: 47.4457
# Epoch 90/100
# 38/38 [==============================] - 0s 1ms/step - loss: 2984.8718 - mean_absolute_error: 29.0125 - val_loss: 8388.1768 - val_mean_absolute_error: 47.2141
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3131.1624 - mean_absolute_error: 31.0341 - val_loss: 8448.9404 - val_mean_absolute_error: 47.2866
# Epoch 92/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3034.8000 - mean_absolute_error: 30.4910 - val_loss: 8378.6973 - val_mean_absolute_error: 49.2307
# Epoch 93/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3007.6160 - mean_absolute_error: 29.8944 - val_loss: 8733.0645 - val_mean_absolute_error: 49.2630
# Epoch 94/100
# 38/38 [==============================] - 0s 1ms/step - loss: 2948.7620 - mean_absolute_error: 29.1436 - val_loss: 8353.8828 - val_mean_absolute_error: 46.8533
# Epoch 95/100
# 38/38 [==============================] - 0s 1ms/step - loss: 2958.4026 - mean_absolute_error: 28.8507 - val_loss: 8383.6289 - val_mean_absolute_error: 48.6593
# Epoch 96/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3001.0823 - mean_absolute_error: 30.3242 - val_loss: 8285.8828 - val_mean_absolute_error: 47.1011
# Epoch 97/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3036.7637 - mean_absolute_error: 30.1566 - val_loss: 8778.6816 - val_mean_absolute_error: 49.5697
# Epoch 98/100
# 38/38 [==============================] - 0s 1ms/step - loss: 2954.4727 - mean_absolute_error: 29.0349 - val_loss: 8576.9824 - val_mean_absolute_error: 48.3165
# Epoch 99/100
# 38/38 [==============================] - 0s 1ms/step - loss: 2986.6624 - mean_absolute_error: 29.0752 - val_loss: 8909.8623 - val_mean_absolute_error: 50.0846
# Epoch 100/100
# 38/38 [==============================] - 0s 1ms/step - loss: 3071.9631 - mean_absolute_error: 29.9851 - val_loss: 8308.2275 - val_mean_absolute_error: 46.9367

# %%
test_loss, test_mae = nn.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")
# Out:
# 16/16 [==============================] - 0s 805us/step - loss: 9122.3887 - mean_absolute_error: 50.0785
# Test Loss: 9122.388671875, Test MAE: 50.0784912109375

# %%
# Calculate predictions using the deep learning model
y_pred_nn = nn.predict(X_test)

# Calculate Mean Squared Error (MSE) for the deep learning model
mse_nn = mean_squared_error(y_test, y_pred_nn)

# Calculate Root Mean Squared Error (RMSE) for the deep learning model
rmse_nn = np.sqrt(mse_nn)

# Calculate R-squared for the deep learning model
r2_nn = r2_score(y_test, y_pred_nn)

print("Deep Learning Model - Root Mean Squared Error (RMSE):", rmse_nn)
print("Deep Learning Model - R-squared:", r2_nn)
# Out:
# 16/16 [==============================] - 0s 696us/step
# Deep Learning Model - Root Mean Squared Error (RMSE): 95.51120739320184
# Deep Learning Model - R-squared: 0.6000049241876837
